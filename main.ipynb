# %%
# %%bash
# Out:
# Running cells with '2399401739cf1bc4cbf9bebaaab8bf43_ (Python 3.12.13)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: 'conda install -n 2399401739cf1bc4cbf9bebaaab8bf43_ ipykernel --update-deps --force-reinstall'
